# %%
import numpy as np

# %%
text_in =  np.load('textin_array.npy')
print(text_in[74])
# Out:
# [ 93 121 188 108 131 143  18  17  27 137  83 170 240  34  13 145]

# %%
secret_key = ['54','68','61','74','73','20','6D','79','20','4B','75','6E','67','20','46','75']

subkeys = []
for i in secret_key:

  int_value = int(i,16)
  hex_value = hex(int_value)
  
  subkeys.append(hex_value)

# %%
#Secret_key = "Thisismysecret!!"
#subkeys = []
#subkeys.append("{:02x}".format(ord(c)) for c in Secret_key)

# %%
#!/usr/bin/env python3

from random import randint
import argparse, sys

sbox = []

isbox = []

rcon = [0x01,0x02,0x04,0x08,0x10,0x20,0x40,0x80,0x1b,0x36]

def xtime(a):
    return ((a << 1) & 0xff) ^ (a >> 7)*0x1b

def mixcolumn(b):
    t = b[0] ^ b[1] ^ b[2] ^ b[3]
    u = b[0]
    
    v = b[0] ^ b[1]
    v = xtime(v)
    b[0] = b[0] ^ v ^ t

    v = b[1] ^ b[2]
    v = xtime(v)
    b[1] = b[1] ^ v ^ t

    v = b[2] ^ b[3]
    v = xtime(v)
    b[2] = b[2] ^ v ^ t

    v = b[3] ^ u
    v = xtime(v)
    b[3] = b[3] ^ v ^ t
    
    
def imixcolumn(b):  
    # preprocessing
    u = b[0] ^ b[2]
    u = xtime(xtime(u))
    v = b[1] ^ b[3]
    v = xtime(xtime(v))
    b[0] ^= u
    b[1] ^= v
    b[2] ^= u
    b[3] ^= v
    mixcolumn(b)

    
def MC(state):
    for col in state:
        mixcolumn(col)


def iMC(state):
    for col in state:
        imixcolumn(col)

    
def SR(state):
    state[0][1], state[1][1], state[2][1], state[3][1] = state[1][1], state[2][1], state[3][1], state[0][1]
    state[0][2], state[1][2], state[2][2], state[3][2] = state[2][2], state[3][2], state[0][2], state[1][2]
    state[0][3], state[1][3], state[2][3], state[3][3] = state[3][3], state[0][3], state[1][3], state[2][3]

def SB(state):
    for i in range(4):
        state[i] = [sbox[b] for b in state[i]]


def AKsubkeys(state, subkeys, rnd):
    for i in range(4):
        for j in range(4):
            #print(type(state[i][j]))
            #print(type(subkeys[rnd*16 + i *4 + j]))

            print(type(state[i][j]))
            print(type(subkeys[i][j]))
            state[i][j] = state[i][j]^subkeys[i*j]

def encrypt_aes_subkeys(plaintext, subkeys):
    print(plaintext)
    state = [plaintext[i:i+4] for i in range(0,16,4)]  
    print(subkeys[0:16])      
    AKsubkeys(state,subkeys,0)
        
    # round 1 to nr-1
    for rnd in range(1, 10):
        SB(state)
        SR(state)
        MC(state)
        AKsubkeys(state, subkeys, rnd)
        
    # last round
    SB(state)
    SR(state)
    AKsubkeys(state, subkeys, 10)

    return bytes([state[i][j] for i in range(4) for j in range(4)])

# %%
#print(type(new_string))
new_string = np.array([0x54,0x68,0x61,0x74,0x73,0x20,0x64,0x79,0x20,0x42,0x75,0x65,0x67,0x20,0x46,0x75])
encrypt_aes_subkeys(text_in[74],new_string)
# Out:
# [ 21 105  97 116 144  33 100 104  33 227 134 101 103  32  87 100]
# [ 84 104  97 116 115  32 100 121  32  66 117 101 103  32  70 117]
# <class 'numpy.uint8'>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-a9ef7e82db94> in <module>()
#       1 #print(type(new_string))
#       2 new_string = np.array([0x54,0x68,0x61,0x74,0x73,0x20,0x64,0x79,0x20,0x42,0x75,0x65,0x67,0x20,0x46,0x75])
# ----> 3 encrypt_aes_subkeys(text_in[74],new_string)
#
# <ipython-input-37-d1a5c5910f36> in encrypt_aes_subkeys(plaintext, subkeys)
#     111     state = [plaintext[i:i+4] for i in range(0,16,4)]
#     112     print(subkeys[0:16])
# --> 113     AKsubkeys(state,subkeys,0)
#     114
#     115     # round 1 to nr-1
#
# <ipython-input-37-d1a5c5910f36> in AKsubkeys(state, subkeys, rnd)
#     104
#     105             print(type(state[i][j]))
# ...
